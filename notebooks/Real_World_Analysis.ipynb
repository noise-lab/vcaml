# %% [markdown]
# # Real-World Analysis
#
# Loads results from `data/real_world_data_intermediates/`.
# Run `make train-rw` from the project root first.

# %% [markdown]
# ## Setup

# %%
from vcaml.io.mlflow_loader import load_results
import os, sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import mean_absolute_error, accuracy_score, confusion_matrix

matplotlib.rcParams.update({
    'font.size': 8, 'figure.figsize': [1.0*3.125, 1.5*0.8],
    'legend.fontsize': 10, 'legend.fancybox': True,
    'font.family': 'serif', 'font.sans-serif': 'Times',
    'xtick.major.width': 0.2, 'xtick.minor.width': 0.4,
    'ytick.major.width': 0.2, 'ytick.minor.width': 0.4,
    'text.usetex': False, 'axes.labelsize': 14,
    'axes.spines.right': False, 'axes.spines.top': False,
})
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Configuration

# %%
EXPERIMENT_NAME       = 'real_world_data'
MLFLOW_TRACKING_URI   = str(Path('..').resolve() / 'mlruns')
K_FOLDS               = 5
METRICS               = ['framesReceivedPerSecond', 'bitrate', 'frame_jitter', 'frameHeight']
METHODS               = ['IP/UDP ML', 'IP/UDP Heuristic', 'RTP ML', 'RTP Heuristic']
VCAS                  = ['meet', 'teams']
FEATURE_TAG           = 'LSTATS-TSTATS'

# %% [markdown]
# ## Load Results

# %%
FEATURE_MAP = {
    'l_mean': 'Size [mean]', 'l_std': 'Size [stdev]', 'l_min': 'Size [min]',
    'l_max': 'Size [max]', 'l_q1': 'Size [Q1]', 'l_q2': 'Size [median]',
    'l_q3': 'Size [Q3]', 'l_num_pkts': '# packets', 'l_num_bytes': '# bytes',
    'l_num_unique': '# unique sizes',
    't_mean': 'IAT [mean]', 't_std': 'IAT [stdev]', 't_min': 'IAT [min]',
    't_max': 'IAT [max]', 't_q1': 'IAT [Q1]', 't_q2': 'IAT [median]',
    't_q3': 'IAT [Q3]', 't_burst_count': '# Microbursts',
    'vid_ts_unique': '# unique RTP TS', 'rtx_ts_unique': '# unique RTX TS',
    'vid_marker_sum': 'Marker bit sum', 'rtx_marker_sum': 'RTX marker sum',
    'common_vid_rtx_ts_unique': '# common RTP TS',
    'ooo_seqno_vid': '# RTP seq breaks',
    'buffer_time_mean': 'Buffer time [mean]', 'buffer_time_std': 'Buffer time [stdev]',
    'buffer_time_min': 'Buffer time [min]', 'buffer_time_max': 'Buffer time [max]',
    'buffer_time_q1': 'Buffer time [Q1]', 'buffer_time_q2': 'Buffer time [Q2]',
    'buffer_time_q3': 'Buffer time [Q3]',
    'rtp_lag_mean': 'RTP lag [mean]', 'rtp_lag_std': 'RTP lag [stdev]',
    'rtp_lag_min': 'RTP lag [min]', 'rtp_lag_max': 'RTP lag [max]',
    'rtp_lag_q1': 'RTP lag [Q1]', 'rtp_lag_q2': 'RTP lag [median]',
    'rtp_lag_q3': 'RTP lag [Q3]',
}

# %%
df, f_imp = load_results(
    EXPERIMENT_NAME, METRICS, METHODS, VCAS,
    k_folds=K_FOLDS, feature_tag=FEATURE_TAG,
    tracking_uri=MLFLOW_TRACKING_URI,
)
print(f'Loaded {len(df):,} rows across {df["metric"].nunique()} metrics, '
      f'{df["method"].nunique()} methods, {df["VCA"].nunique()} VCAs')
df['VCA'] = df['VCA'].replace({'meet': 'Meet', 'teams': 'Teams'})
df.head(3)

# %%
df.to_csv('real_world_results.csv', index=False)
# df = pd.read_csv('real_world_results.csv', index_col=None)

# %% [markdown]
# ## Overall Numbers (MAE)

# %%
tmp = df.copy()
tmp.loc[tmp['metric'] == 'bitrate', 'abs_deviation'] /= 1000
for metric, label in [('framesReceivedPerSecond', 'FPS'),
                       ('bitrate', 'Bitrate (kbps)'),
                       ('frame_jitter', 'Frame Jitter (ms)')]:
    sub = tmp[tmp['metric'] == metric]
    if sub.empty:
        continue
    print(f'\n--- {label} ---')
    print(sub.groupby(['method', 'VCA'])['abs_deviation'].mean()
            .unstack('VCA').to_string(float_format='%.2f'))

# %% [markdown]
# ## Deviations Across Methods

# %%
colors = [
    '#0070ff','#ff0070','#00ff0f','#ffcf00','#b0ff00','#00b0ff',
    '#70ff00','#ff0030','#00ff8f','#ff4f00','#ff00b0','#8f00ff',
    '#00ffcf','#ff0f00','#30ff00','#00ff4f','#cf00ff','#00f0ff',
    '#f0ff00','#ff00f0','#4f00ff','#0f00ff','#ff8f00','#0030ff',
]

# %%
from matplotlib.patches import PathPatch

def adjust_box_widths(g, fac):
    for ax in g.axes:
        for c in ax.get_children():
            if isinstance(c, PathPatch):
                p = c.get_path()
                verts = p.vertices[:-1]
                xmin, xmax = np.min(verts[:, 0]), np.max(verts[:, 0])
                xmid, xhalf = 0.5*(xmin+xmax), 0.5*(xmax-xmin)
                xmin_new, xmax_new = xmid - fac*xhalf, xmid + fac*xhalf
                verts[verts[:, 0] == xmin, 0] = xmin_new
                verts[verts[:, 0] == xmax, 0] = xmax_new
                for l in ax.lines:
                    if np.all(l.get_xdata() == [xmin, xmax]):
                        l.set_xdata([xmin_new, xmax_new])

def plot_fps(df_fps, vca):
    meet = df_fps[df_fps['VCA'] == vca].copy()
    llabels, parts = {}, []
    for method in df_fps['Method'].unique():
        d = meet[meet['Method'] == method].copy()
        if d.empty:
            continue
        mae = round(mean_absolute_error(d['Prediction'], d['Ground Truth']), 2)
        label = f'{method} ({mae})'
        d['Method'] = label
        parts.append(d)
        llabels[method] = label
    if not parts:
        return
    meet = pd.concat(parts, axis=0)
    fig, ax = plt.subplots(1, 1)
    for method, ls, color in [('RTP ML', None, colors[0]), ('IP/UDP ML', None, colors[1]),
                               ('RTP Heuristic', '--', colors[0]), ('IP/UDP Heuristic', '--', colors[1])]:
        sub = meet[meet['Method'].str.startswith(method)]
        if not sub.empty:
            sns.ecdfplot(sub, x='deviation', ls=ls, color=color, ax=ax,
                         label=llabels.get(method, method), linewidth=2)
    plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.15), ncol=2, frameon=False, prop={'size': 8})
    plt.grid(visible=True)
    plt.xlim([-10, 10])
    plt.xlabel('Frame Rate Error [FPS]', fontsize=10)
    plt.ylabel('CDF', fontsize=10)
    os.makedirs('paper_plots', exist_ok=True)
    plt.savefig(f'paper_plots/{vca}_fps_error.pdf', bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### Frame Rate

# %%
fig = plt.figure(figsize=(1.3*3.125, 1.5*1.0))
df_fps = df[df['metric'] == 'framesReceivedPerSecond'].copy().rename(columns={'method': 'Method'})
medians = df_fps.groupby(['VCA', 'Method'])['deviation'].quantile(0.9).values
maes    = [str(round(x, 1)) for x in df_fps.groupby(['VCA', 'Method'])['abs_deviation'].mean().values]
n_methods = df_fps['Method'].nunique()
palette = ['#003f5c', '#7a5195', '#ef5675', '#ffa600'][:n_methods]
g = sns.boxplot(data=df_fps, x='VCA', y='deviation', hue='Method',
                showfliers=False, whis=[10, 90], width=0.95, palette=palette)
adjust_box_widths(fig, 0.8)
ind = 0
for tick in range(len(g.get_xticklabels())):
    for j in range(n_methods):
        g.text(tick+0.3-0.2*j, medians[ind+j]+.5, maes[ind+j], ha='center', color='k', fontsize=8)
    ind += n_methods
plt.xlabel('VCA', fontsize=10)
plt.ylabel('FPS Error', fontsize=10)
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2, frameon=False, prop={'size': 8})
plt.gca().yaxis.grid(True)
plt.ylim([-6.5, 4])
os.makedirs('paper_plots', exist_ok=True)
plt.savefig('paper_plots/fps_error_boxplot_rw.pdf', bbox_inches='tight')
plt.show()
for vca in sorted(df['VCA'].unique()):
    plot_fps(df_fps, vca)

# %%
df_fps = df[df['metric'] == 'framesReceivedPerSecond'].rename(columns={'method': 'Method'}).copy()
for method in ['IP/UDP ML', 'RTP ML']:
    print(f'\n--- {method}: % predictions within ±2 FPS ---')
    for vca in sorted(df['VCA'].unique()):
        sub = df_fps[(df_fps['Method'] == method) & (df_fps['VCA'] == vca)]
        if sub.empty:
            continue
        pct = 100*len(sub[(sub['deviation'] >= -2) & (sub['deviation'] <= 2)]) / len(sub)
        print(f'  {vca}: {pct:.1f}%')

# %% [markdown]
# ### Bitrate

# %%
def plot_bitrate(df_bitrate, vca):
    meet = df_bitrate[df_bitrate['VCA'] == vca].copy()
    llabels, parts = {}, []
    for method in df_bitrate['Method'].unique():
        d = meet[meet['Method'] == method].copy()
        if d.empty:
            continue
        mae = round(mean_absolute_error(d['Prediction'], d['Ground Truth'])/1000, 2)
        label = f'{method} ({mae})'
        d['Method'] = label
        parts.append(d)
        llabels[method] = label
    if not parts:
        return
    meet = pd.concat(parts, axis=0)
    fig, ax = plt.subplots(1, 1)
    for method, ls, color in [('RTP ML', None, colors[0]), ('IP/UDP ML', None, colors[1]),
                               ('RTP Heuristic', '--', colors[0]), ('IP/UDP Heuristic', '--', colors[1])]:
        sub = meet[meet['Method'].str.startswith(method)]
        if not sub.empty:
            sns.ecdfplot(sub, x='rel_deviation', ls=ls, color=color, ax=ax,
                         label=llabels.get(method, method), linewidth=2)
    plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.15), ncol=2, frameon=False, prop={'size': 8})
    plt.grid(visible=True)
    plt.xlim([-1, 1])
    plt.xlabel('Relative Bitrate Error', fontsize=10)
    plt.ylabel('CDF', fontsize=10)
    os.makedirs('paper_plots', exist_ok=True)
    plt.savefig(f'paper_plots/{vca}_bitrate_error.pdf', bbox_inches='tight')
    plt.show()

# %%
fig = plt.figure(figsize=(1.3*3.125, 1.5*1.0))
df_bitrate = df[df['metric'] == 'bitrate'].copy()
df_bitrate['deviation'] /= 1000
df_bitrate['rel_deviation'] = df_bitrate['deviation'] / (df_bitrate['Ground Truth'] / 1000)
df_bitrate = df_bitrate.rename(columns={'method': 'Method'})
df_bitrate.replace([np.inf, -np.inf], np.nan, inplace=True)
medians = df_bitrate.groupby(['VCA', 'Method'])['rel_deviation'].quantile(0.9).values
maes = [str(round(x*100))+'%' for x in df_bitrate.groupby(['VCA', 'Method'])['rel_deviation'].mean().values]
n_methods = df_bitrate['Method'].nunique()
palette = ['#003f5c', '#7a5195', '#ef5675', '#ffa600'][:n_methods]
g = sns.boxplot(data=df_bitrate, x='VCA', y='rel_deviation', hue='Method',
                showfliers=False, whis=[10, 90], palette=palette)
adjust_box_widths(fig, 0.8)
ind = 0
for tick in range(len(g.get_xticklabels())):
    for j in range(n_methods):
        g.text(tick+0.3-0.2*j, medians[ind+j]+.02, maes[ind+j], ha='center', color='k', fontsize=8)
    ind += n_methods
plt.xlabel('VCA', fontsize=10)
plt.ylabel('Bitrate Relative Error', fontsize=10)
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2, frameon=False, prop={'size': 8})
plt.gca().yaxis.grid(True)
plt.ylim([-0.2, 0.6])
os.makedirs('paper_plots', exist_ok=True)
plt.savefig('paper_plots/bitrate_error_boxplot_rw.pdf', bbox_inches='tight')
plt.show()
for vca in sorted(df['VCA'].unique()):
    plot_bitrate(df_bitrate, vca)

# %%
df_bitrate = df[df['metric'] == 'bitrate'].copy()
df_bitrate['deviation'] /= 1000
df_bitrate['rel_deviation'] = df_bitrate['deviation'] / (df_bitrate['Ground Truth'] / 1000)
df_bitrate = df_bitrate.rename(columns={'method': 'Method'})
df_bitrate.replace([np.inf, -np.inf], np.nan, inplace=True)
for method in ['IP/UDP ML', 'RTP ML']:
    print(f'\n--- {method}: % predictions within ±25% relative error ---')
    for vca in sorted(df['VCA'].unique()):
        sub = df_bitrate[(df_bitrate['Method'] == method) & (df_bitrate['VCA'] == vca)].dropna(subset=['rel_deviation'])
        if sub.empty:
            continue
        pct = 100*len(sub[(sub['rel_deviation'] >= -0.25) & (sub['rel_deviation'] <= 0.25)]) / len(sub)
        print(f'  {vca}: {pct:.1f}%')

# %% [markdown]
# ### Frame Jitter

# %%
def plot_jitter(df_jitter, vca):
    meet = df_jitter[df_jitter['VCA'] == vca].copy()
    llabels, parts = {}, []
    for method in df_jitter['Method'].unique():
        d = meet[meet['Method'] == method].copy()
        if d.empty:
            continue
        mae = round(mean_absolute_error(d['Prediction'], d['Ground Truth']), 2)
        label = f'{method} ({mae})'
        d['Method'] = label
        parts.append(d)
        llabels[method] = label
    if not parts:
        return
    meet = pd.concat(parts, axis=0)
    fig, ax = plt.subplots(1, 1)
    for method, ls, color in [('RTP ML', None, colors[0]), ('IP/UDP ML', None, colors[1]),
                               ('RTP Heuristic', '--', colors[0]), ('IP/UDP Heuristic', '--', colors[1])]:
        sub = meet[meet['Method'].str.startswith(method)]
        if not sub.empty:
            sns.ecdfplot(sub, x='deviation', ls=ls, color=color, ax=ax,
                         label=llabels.get(method, method), linewidth=2)
    plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.15), ncol=2, frameon=False, prop={'size': 8})
    plt.grid(visible=True)
    plt.xlim([-100, 100])
    plt.xlabel('Frame Jitter Error [ms]', fontsize=10)
    plt.ylabel('CDF', fontsize=10)
    os.makedirs('paper_plots', exist_ok=True)
    plt.savefig(f'paper_plots/{vca}_jitter_error.pdf', bbox_inches='tight')
    plt.show()

# %%
fig = plt.figure(figsize=(1.3*3.125, 1.5*1.0))
df_jitter = df[df['metric'] == 'frame_jitter'].copy().rename(columns={'method': 'Method'})
medians = df_jitter.groupby(['VCA', 'Method'])['deviation'].quantile(0.9).values
maes    = [str(round(x)) for x in df_jitter.groupby(['VCA', 'Method'])['abs_deviation'].mean().values]
n_methods = df_jitter['Method'].nunique()
palette = ['#003f5c', '#7a5195', '#ef5675', '#ffa600'][:n_methods]
g = sns.boxplot(data=df_jitter, x='VCA', y='deviation', hue='Method',
                showfliers=False, whis=[10, 90], palette=palette)
adjust_box_widths(fig, 0.8)
ind = 0
for tick in range(len(g.get_xticklabels())):
    for j in range(n_methods):
        g.text(tick+0.3-0.2*j, medians[ind+j]+2, maes[ind+j], ha='center', color='k', fontsize=8)
    ind += n_methods
plt.ylim([-15, 50])
plt.xlabel('VCA', fontsize=10)
plt.ylabel('Frame Jitter Error [ms]', fontsize=10)
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2, frameon=False, prop={'size': 8})
plt.gca().yaxis.grid(True)
os.makedirs('paper_plots', exist_ok=True)
plt.savefig('paper_plots/jitter_error_boxplot_rw.pdf', bbox_inches='tight')
plt.show()
print('\nMean ground-truth jitter per VCA:')
print(df_jitter.groupby('VCA')['Ground Truth'].mean())
for vca in sorted(df['VCA'].unique()):
    plot_jitter(df_jitter, vca)

# %%
df_jitter = df[df['metric'] == 'frame_jitter'].rename(columns={'method': 'Method'}).copy()
teams = df_jitter[df_jitter['VCA'] == 'Meet']
if not teams.empty:
    example_file = teams['csv_file'].iloc[min(100, len(teams)-1)]
    for method, color, fname_suffix in [
        ('IP/UDP ML',       '#023eff', 'ip_udp_ml'),
        ('RTP ML',          '#023eff', 'rtp_ml'),
        ('IP/UDP Heuristic','#023eff', 'ip_udp_heuristic'),
        ('RTP Heuristic',   '#023eff', 'rtp_heuristic'),
    ]:
        tdf = teams[(teams['csv_file'] == example_file) & (teams['Method'] == method)].sort_values('ts').copy()
        if tdf.empty:
            continue
        tdf['ts'] = tdf['ts'] - tdf['ts'].min()
        fig, ax = plt.subplots(1, 1)
        tdf.plot('ts', 'Prediction',   ax=ax, label=method,         color=color,     linewidth=2)
        tdf.plot('ts', 'Ground Truth', ax=ax, label='Ground Truth', color='#f14cc1', linewidth=2)
        plt.grid(visible=True)
        plt.xlabel('Time [sec]', fontsize=10)
        plt.ylabel('Frame Jitter [ms]', fontsize=10)
        plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=2, frameon=False, prop={'size': 8})
        ax.spines[['right', 'top']].set_visible(False)
        os.makedirs('paper_plots', exist_ok=True)
        plt.savefig(f'paper_plots/jitter_{fname_suffix}_rw.pdf', bbox_inches='tight')
        plt.show()

# %% [markdown]
# ## Resolution Confusion Matrices

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

df_fh = df[df['metric'] == 'frameHeight'].copy()

def bin_res(x):
    if x > 0 and x <= 240:   return '(0, 240]'
    if x > 240 and x <= 480: return '(240, 480]'
    if x > 480 and x <= 720: return '(480, 720]'
    return str(x)

os.makedirs('paper_plots', exist_ok=True)
for vca in sorted(df['VCA'].unique()):
    sub = df_fh[df_fh['VCA'] == vca].copy()
    if sub.empty:
        print(f'No frameHeight data for {vca}')
        continue
    if vca == 'Teams':
        sub['Prediction']   = sub['Prediction'].apply(bin_res)
        sub['Ground Truth'] = sub['Ground Truth'].apply(bin_res)
    print(f'\n=== {vca} frameHeight values: {sorted(sub["Ground Truth"].unique())} ===')
    for method_label in ['IP/UDP ML', 'RTP ML']:
        m_sub = sub[sub['method'] == method_label]
        if m_sub.empty:
            continue
        labels = sorted(m_sub['Ground Truth'].unique())
        ccounts = [int((m_sub['Ground Truth'] == l).sum()) for l in labels]
        cm = confusion_matrix(y_true=m_sub['Ground Truth'], y_pred=m_sub['Prediction'], labels=labels)
        acc = round(100*accuracy_score(m_sub['Ground Truth'], m_sub['Prediction']), 2)
        cm_norm = 100 * cm / cm.sum(axis=1, keepdims=True)
        cm_norm[np.isnan(cm_norm)] = 0
        p = len(labels)
        text = np.array([f'{a:.2f}%' for a in cm_norm.flatten()]).reshape(p, p)
        fig, ax = plt.subplots(1, 1, figsize=(2.5, 2.5))
        sns.heatmap(cm_norm, annot=text, cmap='Reds', fmt='', cbar=False,
                    xticklabels=labels, yticklabels=labels, ax=ax)
        for i, cnt in enumerate(ccounts):
            plt.annotate(f' Total={cnt}', xy=(p, i+0.5))
        ax.set_title(f'{vca} {method_label}\nAccuracy = {acc}%')
        ax.set_ylabel('Actual frame height', fontsize=10)
        ax.set_xlabel('Predicted frame height', fontsize=10)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
        safe = method_label.replace('/', '_').replace(' ', '_')
        plt.savefig(f'paper_plots/{vca}_resolution_cm_{safe}_rw.pdf', bbox_inches='tight')
        plt.show()

print('\nGround-truth frameHeight distribution (Teams):')
print(df_fh[df_fh['VCA'] == 'Teams']['Ground Truth'].value_counts(normalize=True).mul(100).round(1))

# %% [markdown]
# ## Feature Importance Scores
#
# > Only available for ML methods.

# %%
for metric in METRICS:
    if metric == 'frameHeight':
        continue
    for vca in sorted(df['VCA'].unique()):
        vca_raw = {'Meet': 'meet', 'Teams': 'teams'}.get(vca, vca)
        scores = {}
        for cv in range(1, K_FOLDS+1):
            fi = f_imp.get(metric, {}).get(cv, {}).get(vca_raw, {})
            for feat, imp in fi.items():
                scores.setdefault(FEATURE_MAP.get(feat, feat), []).append(100*imp)
        if not scores:
            print(f'No feature importances for {vca}/{metric}')
            continue
        fig, ax = plt.subplots(1, 1, figsize=[3.125, 1.5])
        topk = pd.Series({k: np.mean(v) for k,v in scores.items()}).sort_values(ascending=False).head(5).sort_values()
        plt.barh(topk.index, topk.values, color=colors[5])
        plt.xlabel('Feature Importance [%]', fontsize=10)
        plt.title(f'{vca} — {metric}')
        plt.xlim([0, 100])
        plt.gca().xaxis.grid(True)
        ax.spines[['right', 'top']].set_visible(False)
        os.makedirs('paper_plots', exist_ok=True)
        plt.savefig(f'paper_plots/{vca}_{metric}_feature_importance_rw.pdf', bbox_inches='tight')
        plt.show()

# %% [markdown]
# ## Ground Truth Distributions

# %%
for metric, xlabel, xlim in [
    ('bitrate',                'Bitrate [kbps]',    (0, 5000)),
    ('framesReceivedPerSecond','Frame Rate [FPS]',   (0, 60)),
    ('frame_jitter',           'Frame Jitter [ms]', (0, 100)),
]:
    sub = df[df['metric'] == metric]
    if sub.empty:
        continue
    fig, ax = plt.subplots(1, 1)
    for vca, color in zip(sorted(df['VCA'].unique()), ['#023eff', '#f14cc1']):
        d = sub[sub['VCA'] == vca]
        vals = d['Ground Truth'] / (1000 if metric == 'bitrate' else 1)
        sns.ecdfplot(data=vals, ax=ax, label=vca, color=color, linewidth=2)
    plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=3, frameon=False)
    plt.xlabel(xlabel, fontsize=10)
    plt.ylabel('CDF', fontsize=10)
    plt.xlim(xlim)
    plt.grid(visible=True)
    ax.spines[['right', 'top']].set_visible(False)
    os.makedirs('paper_plots', exist_ok=True)
    plt.savefig(f'paper_plots/{metric}_gt_distribution_rw.pdf', bbox_inches='tight')
    plt.show()
